# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales = pd.read_csv("historical_automobile_sales.csv")
sales
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# ...

# %% [markdown]
# Q 1: Develop a Line chart using the functionality of pandas to show how
# automobile sales fluctuate from year to year.

# %%
yearly_sales = sales.groupby("Year")["Automobile_Sales"].sum().reset_index()
plt.plot(yearly_sales["Year"], yearly_sales["Automobile_Sales"], marker="o", linestyle="--", color="b",label = "Automobile_Sales")
plt.xlabel("Year")
plt.ylabel("Total Automobile Sales")
plt.title("Yearly Automobile Sales Fluctuation")
plt.legend()
plt.grid(True)

# %% [markdown]
# Q 2: Plot different lines for categories of vehicle type and analyze the trend
# to answer the question Is there a noticeable difference in sales trends
# between different vehicle types during recession periods?

# %%
recession_periods = sales[sales["Recession"] == 1]
recession_periods
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 108  12/31/2009  2009   Dec          1                94.83
# 109   9/30/2020  2020   Sep          1               111.62
# 110  10/31/2020  2020   Oct          1                84.48
# 111  11/30/2020  2020   Nov          1               112.39
# 112  12/31/2020  2020   Dec          1                97.85
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# ...

# %%
Sale= recession_periods.groupby(['Year','Vehicle_Type'])['Automobile_Sales'].sum().reset_index()
Sale
sns.lineplot(data=Sale,x='Year',y='Automobile_Sales',hue='Vehicle_Type',marker='*')
plt.title('Automobile Sales Trends by Vehicle Type')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.legend()
plt.show()

# %% [markdown]
# Q 3: Use the functionality of Seaborn Library to create a visualization to compare
# the sales trend per vehicle type for a recession period with a non- recession
# period.

# %%
Sale= sales.groupby(['Year','Vehicle_Type','Recession'])['Automobile_Sales'].sum().reset_index()
plt.figure(figsize=(12,8))
sns.lineplot(data=Sale,x='Year',y='Automobile_Sales',hue='Vehicle_Type',marker='o',linestyle='dashed',style='Recession')
plt.title('Sales Trends per Vehicle Type during recession')
plt.show()

# %% [markdown]
# Q 4: Now you want to compare the sales of different vehicle types during a recession and a non-recession period

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=sales,x='Vehicle_Type',y='Automobile_Sales',hue='Recession')
plt.title('Comparison of Sales During Recession vs Non-Recession')
plt.xticks(rotation=45)
plt.ylabel('Total Sales')
plt.show()
